# %% [markdown]
# <a href="https://colab.research.google.com/github/AwesomeAru/Machine-Learning/blob/main/K_means_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("../content/housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
#  we are clustering 'latitude' and 'longitute' with 'median_income'(median income) to create economic segments in different regions of California

# %%
X = df.loc[:, ["median_income", "latitude", "longitude"]]
X.head()
# Out:
#    median_income  latitude  longitude
# 0         8.3252     37.88    -122.23
# 1         8.3014     37.86    -122.22
# 2         7.2574     37.85    -122.24
# 3         5.6431     37.85    -122.25
# 4         3.8462     37.85    -122.25

# %% [markdown]
# k-means clustering is sensitive to scale. Our features are already roughly on the same scale, so we'll leave them as-is.

# %%
# Create cluster feature
kmeans = KMeans(n_clusters=6)
X["Cluster"] = kmeans.fit_predict(X)
X["Cluster"] = X["Cluster"].astype("category")

X.head()
# Out:
#    median_income  latitude  longitude Cluster
# 0         8.3252     37.88    -122.23       5
# 1         8.3014     37.86    -122.22       5
# 2         7.2574     37.85    -122.24       5
# 3         5.6431     37.85    -122.25       5
# 4         3.8462     37.85    -122.25       2

# %%
sns.relplot(
    x="longitude", y="latitude", hue="Cluster", data=X, height=6,
);

# %% [markdown]
# The target in this dataset is MedHouseVal (median house value). These box-plots show the distribution of the target within each cluster.

# %%
X["median_house_value"] = df["median_house_value"]
sns.catplot(x="median_house_value", y="Cluster", data=X, kind="boxen", height=6);
